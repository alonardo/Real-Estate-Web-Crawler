# %%
from re import A
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import openpyxl
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 999
df = pd.read_excel(r'C:\Users\aalon\OneDrive\Desktop\python\crawler\targets.xlsx')
df['prop_locat']
df['market_status'] = np.nan
df[['prop_locat','market_status']]
# Out:
#                     prop_locat  market_status
# 0               7633 S MAIN ST            NaN
# 1            799 W COLISEUM WY            NaN
# 2            718 W COLISEUM WY            NaN
# 3               7380 S MAIN ST            NaN
# 4               7592 S MAIN ST            NaN
# 5             7657 S HOLDEN ST            NaN
# 6                 983 W 7800 S            NaN
# 7             7812 S HOLDEN ST            NaN
# 8             7838 S HOLDEN ST            NaN
# 9              759 W CENTER ST            NaN
# 10            7835 S HOLDEN ST            NaN
# 11             726 W LENNOX ST            NaN
# 12              7804 S MAIN ST            NaN
# 13              7826 S MAIN ST            NaN
# 14              7940 S MAIN ST            NaN
# 15             865 W CENTER ST            NaN
# 16              8018 S MAIN ST            NaN
# 17              8038 S MAIN ST            NaN
# 18           8095 S SEGHINI DR            NaN
# 19           8090 S SEGHINI DR            NaN
# 20                795 W IVY DR            NaN
# 21   752 BINGHAM JUNCTION BLVD            NaN
# 22   787 BINGHAM JUNCTION BLVD            NaN
# 23   743 BINGHAM JUNCTION BLVD            NaN
# 24   783 BINGHAM JUNCTION BLVD            NaN
# 25   781 BINGHAM JUNCTION BLVD            NaN
# 26            554 W WASATCH ST            NaN
# 27              8381 S MAIN ST            NaN
# 28    1012 W JORDAN RIVER BLVD            NaN
# 29                6968 S 700 W            NaN
# 30        6941 S RIVER GATE DR            NaN
# 31        6967 S RIVER GATE DR            NaN
# 32          7158 S FLSMIDTH DR            NaN
# 33         7210 S FL SMIDTH DR            NaN
# 34      901 W LEGACY CENTER WY            NaN
# 35      910 W LEGACY CENTER WY            NaN
# 36                7020 S 700 W            NaN
# 37     7087 S BINGHAM JCT BLVD            NaN
# 38     7101 S BINGHAM JCT BLVD            NaN
# 39     7121 S BINGHAM JCT BLVD            NaN
# 40     7149 S BINGHAM JCT BLVD            NaN
# 41     7165 S BINGHAM JCT BLVD            NaN
# 42     7171 S BINGHAM JCT BLVD            NaN
# 43     7111 S BINGHAM JCT BLVD            NaN
# 44     7115 S BINGHAM JCT BLVD            NaN
# 45     7141 S BINGHAM JCT BLVD            NaN
# 46        6997 S RIVER GATE DR            NaN
# 47     7148 S BINGHAM JCT BLVD            NaN
# 48     6962 S BINGHAM JCT BLVD            NaN
# 49         758 W BLUE VISTA LN            NaN
# 50         740 W BLUE VISTA LN            NaN
# 51         720 W BLUE VISTA LN            NaN
# 52         752 W BLUE VISTA LN            NaN
# 53         736 W BLUE VISTA LN            NaN
# 54         716 W BLUE VISTA LN            NaN
# 55                425 W 7200 S            NaN
# 56                411 W 7200 S            NaN
# 57                401 W 7200 S            NaN
# 58         375 W MILLENNIUM ST            NaN
# 59           7267 S CATALPA ST            NaN
# 60             6990 S STATE ST            NaN
# 61             7144 S STATE ST            NaN
# 62             7148 S STATE ST            NaN
# 63             7140 S STATE ST            NaN
# 64             7148 S STATE ST            NaN
# 65        7304 S COTTONWOOD ST            NaN
# 66                365 W 7200 S            NaN
# 67        7235 S COTTONWOOD ST            NaN
# 68                265 W 7200 S            NaN
# 69                335 W 7200 S            NaN
# 70                195 W 7200 S            NaN
# 71                205 W 7200 S            NaN
# 72                7309 S 180 W            NaN
# 73             7288 S STATE ST            NaN
# 74             7346 S STATE ST            NaN
# 75             7350 S STATE ST            NaN
# 76             7356 S STATE ST            NaN
# 77                 39 W 7200 S            NaN
# 78                 44 W 7500 S            NaN
# 79             7412 S STATE ST            NaN
# 80             7414 S STATE ST            NaN
# 81             7434 S STATE ST            NaN
# 82             7480 S STATE ST            NaN
# 83             7526 S STATE ST            NaN
# 84             7580 S STATE ST            NaN
# 85             159 W CENTER ST            NaN
# 86            7679 S CENTER SQ            NaN
# 87          70-114 W CENTER ST            NaN
# 88             7682 S MAPLE ST            NaN
# 89              52 W CENTER ST            NaN
# 90             7676 S STATE ST            NaN
# 91             7677 S MAPLE ST            NaN
# 92       7638 S STATE ST # A-F            NaN
# 93        7640-7642 S STATE ST            NaN
# 94             7658 S STATE ST            NaN
# 95        7644-7650 S STATE ST            NaN
# 96              30 W CENTER ST            NaN
# 97              24 W CENTER ST            NaN
# 98              49 W CENTER ST            NaN
# 99              35 W CENTER ST            NaN
# 100            7802 S STATE ST            NaN
# 101            7906 S STATE ST            NaN
# 102            7936 S STATE ST            NaN
# 103            7940 S STATE ST            NaN
# 104            7954 S STATE ST            NaN
# 105      7962 S STATE ST # 1-4            NaN
# 106            8090 S STATE ST            NaN
# 107            8100 S STATE ST            NaN
# 108            8136 S STATE ST            NaN
# 109            8142 S STATE ST            NaN
# 110            8164 S STATE ST            NaN
# 111            8200 S STATE ST            NaN
# 112            8160 S STATE ST            NaN
# 113            8244 S STATE ST            NaN
# 114            8200 S STATE ST            NaN
# 115            8228 S STATE ST            NaN
# 116            8408 S STATE ST            NaN
# 117            8430 S STATE ST            NaN
# 118            8452 S STATE ST            NaN
# 119                30 W 8600 S            NaN
# 120            8550 S STATE ST            NaN
# 121            8492 S STATE ST            NaN
# 122            8488 S STATE ST            NaN
# 123            8490 S STATE ST            NaN
# 124        6945 S WELL WOOD RD            NaN
# 125        6945 S WELL WOOD RD            NaN
# 126                71 E 6790 S            NaN
# 127            6928 S STATE ST            NaN
# 128            6990 S STATE ST            NaN
# 129            6878 S STATE ST            NaN
# 130            6930 S STATE ST            NaN
# 131            6895 S STATE ST            NaN
# 132            6905 S STATE ST            NaN
# 133            6935 S STATE ST            NaN
# 134            6957 S STATE ST            NaN
# 135            6885 S STATE ST            NaN
# 136       6909-6911 S STATE ST            NaN
# 137            6863 S STATE ST            NaN
# 138            6801 S STATE ST            NaN
# 139                76 E 6790 S            NaN
# 140            6835 S STATE ST            NaN
# 141       947 E SOUTHUNION AVE            NaN
# 142       948 E SOUTHUNION AVE            NaN
# 143            6990 S STATE ST            NaN
# 144            7000 S STATE ST            NaN
# 145       7046-7056 S STATE ST            NaN
# 146            7070 S STATE ST            NaN
# 147       7160-7182 S STATE ST            NaN
# 148            7009 S STATE ST            NaN
# 149            7065 S STATE ST            NaN
# 150            7045 S STATE ST            NaN
# 151            7095 S STATE ST            NaN
# 152       75 E FORT UNION BLVD            NaN
# 153            7157 S STATE ST            NaN
# 154    25-33 E FORT UNION BLVD            NaN
# 155      263 E FORT UNION BLVD            NaN
# 156      255 E FORT UNION BLVD            NaN
# 157      285 E FORT UNION BLVD            NaN
# 158      195 E FORT UNION BLVD            NaN
# 159            7210 S STATE ST            NaN
# 160            7263 S STATE ST            NaN
# 161            7227 S STATE ST            NaN
# 162            7307 S STATE ST            NaN
# 163            7321 S STATE ST            NaN
# 164            7359 S STATE ST            NaN
# 165            7391 S STATE ST            NaN
# 166      204 E FORT UNION BLVD            NaN
# 167      475 E FORT UNION BLVD            NaN
# 168      665 E FORT UNION BLVD            NaN
# 169      681 E FORT UNION BLVD            NaN
# 170      602 E FORT UNION BLVD            NaN
# 171            7470 S STATE ST            NaN
# 172            7450 S STATE ST            NaN
# 173            7515 S STATE ST            NaN
# 174            7505 S STATE ST            NaN
# 175            7565 S STATE ST            NaN
# 176            7615 S STATE ST            NaN
# 177            7601 S STATE ST            NaN
# 178           26 E FORBUSH AVE            NaN
# 179            7530 S STATE ST            NaN
# 180            7680 S STATE ST            NaN
# 181            7522 S STATE ST            NaN
# 182            7643 S STATE ST            NaN
# 183            7693 S STATE ST            NaN
# 184            7677 S STATE ST            NaN
# 185            7755 S STATE ST            NaN
# 186            7725 S STATE ST            NaN
# 187            8020 S STATE ST            NaN
# 188               340 E 7800 S            NaN
# 189            8370 S STATE ST            NaN
# 190            7816 S STATE ST            NaN
# 191               141 E 8000 S            NaN
# 192        7928 S PINSTRIPE CV            NaN
# 193            8610 S STATE ST            NaN
# 194    7302 S BINGHAM JUNCTION            NaN
# 195    7259 S BINGHAM JCT BLVD            NaN
# 196    7276 S GRANDEUR VIEW WY            NaN
# 197        721 W BLUE VISTA LN            NaN
# 198      547 E FORT UNION BLVD            NaN
# 199      515 E FORT UNION BLVD            NaN
# 200      416 E FORT UNION BLVD            NaN
# 201      398 E FORT UNION BLVD            NaN
# 202      618 E FORT UNION BLVD            NaN
# 203      686 E FORT UNION BLVD            NaN
# 204      453 E FORT UNION BLVD            NaN
# 205      451 E FORT UNION BLVD            NaN
# 206      457 E FORT UNION BLVD            NaN
# 207      463 E FORT UNION BLVD            NaN
# 208      549 E FORT UNION BLVD            NaN
# 209      461 E FORT UNION BLVD            NaN
# 210      537 E FORT UNION BLVD            NaN
# 211      535 E FORT UNION BLVD            NaN
# 212       90 E FORT UNION BLVD            NaN
# 213               7131 S 150 E            NaN
# 214       94 E FORT UNION BLVD            NaN
# 215      160 E FORT UNION BLVD            NaN
# 216      303 E FORT UNION BLVD            NaN
# 217      124 E FORT UNION BLVD            NaN
# 218      455 E FORT UNION BLVD            NaN
# 219      391 E FORT UNION BLVD            NaN
